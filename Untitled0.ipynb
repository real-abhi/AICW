# %% [markdown]
# <a href="https://colab.research.google.com/github/real-abhi/AICW/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dict1 = {1:"umang","department":"DS","city":"jaipur"}

# %%
dict1.keys()
# Out:
# dict_keys([1, 'department', 'city'])

# %%
dict2 = {"name":"abc",2:"hjkd","city":"delhi"}
dict1.update(dict2)
dict1
# Out:
# {1: 'umang', 'department': 'DS', 'city': 'delhi', 'name': 'abc', 2: 'hjkd'}

# %%
dict3 ={"AI/DS":{"name":"bhumika","city":"kota"},
        "CS":{"name":"Abhilasha","city":"jaipur"}}

#nested dictionary

# %%
#Conditional Statements
#if
age = 40
if age >= 18:
  print("you can vote")
# Out:
# you can vote

# %%
age = int(input("Enter your age: "))
if age >= 18:
  print("you can vote")
else:
  print("you can't vote")

#input function takes string value by default
# Out:
# Enter your age: 12
# you can't vote
